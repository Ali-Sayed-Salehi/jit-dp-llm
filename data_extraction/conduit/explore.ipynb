# %% [markdown]
# Import Dependencies

# %%
import requests
import time
import json
from unidiff import PatchSet
from phabricator import Phabricator
from datetime import datetime, timedelta
from pprint import pprint
import pandas as pd
import ast
from dotenv import load_dotenv
import os
# Out:
# /speed-scratch/a_s87063/repos/jit-dp-llm/venv/lib/python3.12/site-packages/phabricator/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources') \

# %% [markdown]
# Set API token and repo URL

# %%
load_dotenv(dotenv_path="../../secrets/.env")

API_TOKEN = os.getenv("CONDUIT_API_TOKEN")

BASE_URL = "https://phabricator.services.mozilla.com/api/"

# %% [markdown]
# Initialize Phabricator client

# %%
phab = Phabricator(token=API_TOKEN, host=BASE_URL)
phab.update_interfaces()
phab.user.whoami()
# Out:
# <Result: {'phid': 'PHID-USER-tkqragx363gqgxck66he', 'userName': 'alal', 'realName': 'Ali', 'image': 'https://mozphab-phabhost-cdn.devsvcprod.mozaws.net/file/data/mphx2gyvrtdt6l3r4hqk/PHID-FILE-i4wttqib4xr2hi2b7nz4/8c9c85-alphanumeric_lato-white_A.png-255%2C255%2C255%2C0.7.png', 'uri': 'https://phabricator.services.mozilla.com/p/alal/', 'roles': ['verified', 'approved', 'activated'], 'primaryEmail': 'a.s.salehi.95@gmail.com'}>

# %% [markdown]
# Get all the repositories

# %%
operation = "diffusion.repository.search"
API_URL = f"{BASE_URL}/{operation}"

payload = {
    "api.token": API_TOKEN,
}

requests.post(API_URL, data=payload).json()
# Out:
# {'result': {'data': [{'id': 49,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-wxrrnneqyw2v3wcqbkfj',
#     'fields': {'name': 'firefox-autoland',
#      'vcs': 'git',
#      'callsign': 'FIREFOXAUTOLAND',
#      'shortName': 'firefox-autoland',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': ['refs/heads/autoland'],
#       'trackRules': [],
#       'permanentRefRules': ['autoland']},
#      'defaultBranch': 'autoland',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1745437005,
#      'dateModified': 1747369572,
#      'policy': {'view': 'public', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 50,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-6m6rsilesn3zw5zrfksg',
#     'fields': {'name': 'firefox-beta',
#      'vcs': 'git',
#      'callsign': 'FIREFOXBETA',
#      'shortName': 'firefox-beta',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': ['refs/heads/beta'],
#       'trackRules': [],
#       'permanentRefRules': ['beta']},
#      'defaultBranch': 'beta',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1745437008,
#      'dateModified': 1747369564,
#      'policy': {'view': 'public', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 9,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-wsfeum6yaue6jsbo7mgm',
#     'fields': {'name': 'comm-central',
#      'vcs': 'hg',
#      'callsign': 'COMMCENTRAL',
#      'shortName': 'comm-central',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1515799714,
#      'dateModified': 1742403307,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 53,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-lqhpe3k6pki2sldl6q36',
#     'fields': {'name': 'firefox-release',
#      'vcs': 'git',
#      'callsign': 'FIREFOXRELEASE',
#      'shortName': 'firefox-release',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': ['refs/heads/release'],
#       'trackRules': [],
#       'permanentRefRules': ['release']},
#      'defaultBranch': 'release',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1745437013,
#      'dateModified': 1747369579,
#      'policy': {'view': 'public', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 11,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-wep66sctxddvhc23odqa',
#     'fields': {'name': 'version-control-tools',
#      'vcs': 'hg',
#      'callsign': 'VCT',
#      'shortName': 'version-control-tools',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1516912937,
#      'dateModified': 1738785978,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 8,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-3lrloqw4qf6fluy2a5ni',
#     'fields': {'name': 'nss',
#      'vcs': 'hg',
#      'callsign': 'NSS',
#      'shortName': 'nss',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1503947377,
#      'dateModified': 1742403308,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 55,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-womlgruzzhegwidgzcrj',
#     'fields': {'name': 'firefox-esr140',
#      'vcs': 'git',
#      'callsign': 'FIREFOXESRONEFOURZERO',
#      'shortName': 'firefox-esr140',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': ['refs/heads/esr140'],
#       'trackRules': [],
#       'permanentRefRules': ['esr140']},
#      'defaultBranch': 'esr140',
#      'description': {'raw': 'Firefox Extended Support Release 140'},
#      'spacePHID': None,
#      'dateCreated': 1749566953,
#      'dateModified': 1750777092,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 51,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-5jfzzuudn2ipueasp4ue',
#     'fields': {'name': 'firefox-esr115',
#      'vcs': 'git',
#      'callsign': 'FIREFOXESRONEONEFIVE',
#      'shortName': 'firefox-esr115',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': ['refs/heads/esr115'],
#       'trackRules': [],
#       'permanentRefRules': ['esr115']},
#      'defaultBranch': 'esr115',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1745437009,
#      'dateModified': 1747369577,
#      'policy': {'view': 'public', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 45,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-v2n7j2cjfhpmbp7zxyoe',
#     'fields': {'name': 'cypress',
#      'vcs': 'hg',
#      'callsign': 'CYPRESS',
#      'shortName': 'cypress',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'The Cypress project branch.'},
#      'spacePHID': None,
#      'dateCreated': 1715009482,
#      'dateModified': 1742382463,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 35,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-c7bjbji7a6qhsy75hq5q',
#     'fields': {'name': 'Elm',
#      'vcs': 'hg',
#      'callsign': 'ELM',
#      'shortName': 'elm',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1631731161,
#      'dateModified': 1742382451,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 28,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-4fu3ffnjgdbasf7z6i43',
#     'fields': {'name': 'nspr',
#      'vcs': 'hg',
#      'callsign': 'NSPR',
#      'shortName': 'nspr',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': "Netscape Portable Runtime (NSPR) provides a platform-neutral API for system level and libc-like functions. The API is used in the Mozilla clients, many of Red Hat's and Oracle's server applications, and other software offerings"},
#      'spacePHID': None,
#      'dateCreated': 1547221168,
#      'dateModified': 1742403309,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 19,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-imfp2vtyrkg4um2qkvv4',
#     'fields': {'name': 'conduit-docs',
#      'vcs': 'git',
#      'callsign': 'CONDUITDOCS',
#      'shortName': 'conduit-docs',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': 'Documentation for Conduit applications\n'},
#      'spacePHID': None,
#      'dateCreated': 1525743664,
#      'dateModified': 1525743972,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 23,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-wbujsxiopp6i3taly5s2',
#     'fields': {'name': 'Review',
#      'vcs': 'git',
#      'callsign': 'REVIEW',
#      'shortName': 'Review',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'main',
#      'description': {'raw': 'Phabricator review submission/management tool.'},
#      'spacePHID': None,
#      'dateCreated': 1532413113,
#      'dateModified': 1743638094,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 7,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-uyzzu3ody5lpogmacs7m',
#     'fields': {'name': 'conduitsuite',
#      'vcs': 'git',
#      'callsign': 'CONDUITSUITE',
#      'shortName': 'conduitsuite',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [],
#       'trackRules': ['main'],
#       'permanentRefRules': ['main']},
#      'defaultBranch': 'main',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1503589888,
#      'dateModified': 1706904636,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 36,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-hbm5xgrpo3t2plvvw5lm',
#     'fields': {'name': 'MozillaBuild',
#      'vcs': 'hg',
#      'callsign': 'MOZILLABUILD',
#      'shortName': 'mozilla-build',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Linux-y tools, but for Windows - essentially just a Mozilla-managed "msys" distibutable with other pieces like Python, `hg`, etc.\nSee [[ https://wiki.mozilla.org/MozillaBuild | the wiki page ]].'},
#      'spacePHID': None,
#      'dateCreated': 1636143301,
#      'dateModified': 1742403310,
#      'policy': {'view': 'public', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 52,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-elwhu6q6qum77n4cppc6',
#     'fields': {'name': 'firefox-esr128',
#      'vcs': 'git',
#      'callsign': 'FIREFOXESRONETWOEIGHT',
#      'shortName': 'firefox-esr128',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': ['refs/heads/esr128'],
#       'trackRules': [],
#       'permanentRefRules': ['esr128']},
#      'defaultBranch': 'esr128',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1745437011,
#      'dateModified': 1747369574,
#      'policy': {'view': 'public', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 4,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-yjtq7hktkone3lj3etpx',
#     'fields': {'name': 'lando-api',
#      'vcs': 'git',
#      'callsign': 'LANDOAPI',
#      'shortName': 'lando-api',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [],
#       'trackRules': ['main'],
#       'permanentRefRules': ['main']},
#      'defaultBranch': 'main',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1503000606,
#      'dateModified': 1706904362,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 42,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-md74zkh2x2jwdqidc7a6',
#     'fields': {'name': 'larch',
#      'vcs': 'hg',
#      'callsign': 'LARCH',
#      'shortName': 'larch',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Larch Repository'},
#      'spacePHID': None,
#      'dateCreated': 1706903845,
#      'dateModified': 1742382457,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 1,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-saax4qdxlbbhahhp2kg5',
#     'fields': {'name': 'mozilla-central',
#      'vcs': 'hg',
#      'callsign': 'MOZILLACENTRAL',
#      'shortName': 'mozilla-central',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1502986064,
#      'dateModified': 1746017898,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 37,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-bjaradtlpdxeajadsmgl',
#     'fields': {'name': 'mozilla-beta',
#      'vcs': 'hg',
#      'callsign': 'BETA',
#      'shortName': 'beta',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Source tree for beta releases of Firefox.'},
#      'spacePHID': None,
#      'dateCreated': 1644349533,
#      'dateModified': 1746035134,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 41,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-mhggdh4klcgft5e3fhfc',
#     'fields': {'name': 'mozilla-esr115',
#      'vcs': 'hg',
#      'callsign': 'ESRONEONEFIVE',
#      'shortName': 'esr115',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1686192861,
#      'dateModified': 1746035135,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 47,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-2s5rbkoedfx4u2xsrz33',
#     'fields': {'name': 'mozilla-esr128',
#      'vcs': 'hg',
#      'callsign': 'ESRONETWOEIGHT',
#      'shortName': 'esr128',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1718290159,
#      'dateModified': 1746035136,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 38,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-obydsoq3yz63vix7gmlw',
#     'fields': {'name': 'mozilla-release',
#      'vcs': 'hg',
#      'callsign': 'RELEASE',
#      'shortName': 'release',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1672781651,
#      'dateModified': 1746035137,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 5,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-lvj6gatf54q6ba5fl4hd',
#     'fields': {'name': 'lando-ui',
#      'vcs': 'git',
#      'callsign': 'LANDOUI',
#      'shortName': 'lando-ui',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [],
#       'trackRules': ['main'],
#       'permanentRefRules': ['main']},
#      'defaultBranch': 'main',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1503000783,
#      'dateModified': 1706904513,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 34,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-uvwibzufoaowvutep3ci',
#     'fields': {'name': 'Pine',
#      'vcs': 'hg',
#      'callsign': 'PINE',
#      'shortName': 'pine',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1620847162,
#      'dateModified': 1742382469,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'admin'}},
#     'attachments': {}},
#    {'id': 48,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-oosyel2g37x5pzak3vw4',
#     'fields': {'name': 'Conduit Testing (Production)',
#      'vcs': 'hg',
#      'callsign': 'CONDUITTESTINGPRODUCTIONREPO',
#      'shortName': 'conduit-testing-production-repo',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'This is a test repo to be used to test various production systems.'},
#      'spacePHID': None,
#      'dateCreated': 1732821437,
#      'dateModified': 1732821893,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 10,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-s3u4ifpsdjudfanrliwj',
#     'fields': {'name': 'mint',
#      'vcs': 'git',
#      'callsign': 'MINT',
#      'shortName': 'mint',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': 'A Minimal TLS 1.3 Implementation in Go'},
#      'spacePHID': None,
#      'dateCreated': 1516074268,
#      'dateModified': 1524499235,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 16,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-kiqorvpaq7yy6mybuvz4',
#     'fields': {'name': 'ci-configuration',
#      'vcs': 'hg',
#      'callsign': 'CICONFIG',
#      'shortName': 'ci-configuration',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Configuration for CI automation relating to the Gecko source code.'},
#      'spacePHID': None,
#      'dateCreated': 1523456273,
#      'dateModified': 1549657483,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 40,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-k5cjbqi4iiq6szazjdv6',
#     'fields': {'name': 'mozilla-esr102',
#      'vcs': 'hg',
#      'callsign': 'ESRONEOHTWO',
#      'shortName': 'esr102',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1672800655,
#      'dateModified': 1728596084,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 14,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-pwe47mg6gisupk4gzqt7',
#     'fields': {'name': 'l10n-fluent-migration',
#      'vcs': 'hg',
#      'callsign': 'FLUENTMIGRATION',
#      'shortName': 'fluent-migration',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Python library to run Fluent migration recipes.'},
#      'spacePHID': None,
#      'dateCreated': 1522993610,
#      'dateModified': 1684245146,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 39,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-lq5r4oqel27ym6tqotjf',
#     'fields': {'name': ' mozilla-esr91',
#      'vcs': 'hg',
#      'callsign': 'ESRNINEONE',
#      'shortName': 'esr91',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1672782244,
#      'dateModified': 1728596079,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 18,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-lzvdu5wxlds2h3r5ht6g',
#     'fields': {'name': 'arcanist',
#      'vcs': 'git',
#      'callsign': 'ARC',
#      'shortName': 'arcanist',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': 'Command line interface for Phabricator'},
#      'spacePHID': None,
#      'dateCreated': 1525101529,
#      'dateModified': 1525931277,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 29,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-liwcrizcwtpjejelpbpd',
#     'fields': {'name': 'taskgraph',
#      'vcs': 'hg',
#      'callsign': 'TASKGRAPH',
#      'shortName': 'taskgraph',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Taskgraph has moved to: https://github.com/taskcluster/taskgraph'},
#      'spacePHID': None,
#      'dateCreated': 1548861976,
#      'dateModified': 1650659476,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 24,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-akfbwfa42curzttfy4l3',
#     'fields': {'name': 'compare-locales',
#      'vcs': 'hg',
#      'callsign': 'COMPARELOCALES',
#      'shortName': 'compare-locales',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Python library to lint Mozilla localizations'},
#      'spacePHID': None,
#      'dateCreated': 1533832927,
#      'dateModified': 1684245132,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 20,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-pcysm3r7myrftnakk4no',
#     'fields': {'name': 'ci-admin',
#      'vcs': 'hg',
#      'callsign': 'CIADMIN',
#      'shortName': 'ci-admin',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1527790291,
#      'dateModified': 1549657523,
#      'policy': {'view': 'public', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 3,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-zgozmu7eybbbdibjpil5',
#     'fields': {'name': 'phabricator-extensions',
#      'vcs': 'git',
#      'callsign': 'PHABRICATOREXTENSIONS',
#      'shortName': 'phabricator-extensions',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [],
#       'trackRules': ['master'],
#       'permanentRefRules': ['master']},
#      'defaultBranch': 'master',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1503000419,
#      'dateModified': 1683300875,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 26,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-buyi76oy7guqgil3ivmw',
#     'fields': {'name': 'commit-telemetry-service',
#      'vcs': 'git',
#      'callsign': 'COMMITTELEMETRY',
#      'shortName': 'commit-telemetry',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': 'A simple queue worker that produces Mozilla code repository telemetry.'},
#      'spacePHID': None,
#      'dateCreated': 1538146372,
#      'dateModified': 1538146613,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 21,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-6x5wjyi4ijmr73fhkqtk',
#     'fields': {'name': 'build-puppet',
#      'vcs': 'git',
#      'callsign': 'BUILDPUPPET',
#      'shortName': 'buildpuppet',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': 'Release Engineering Puppet Infrastructure'},
#      'spacePHID': None,
#      'dateCreated': 1528143094,
#      'dateModified': 1528147376,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 22,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-73x5alupkac3vr6r67za',
#     'fields': {'name': 'Transplant',
#      'vcs': 'git',
#      'callsign': 'TRANSPLANT',
#      'shortName': 'Transplant',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': 'Autoland-Transplant'},
#      'spacePHID': None,
#      'dateCreated': 1528176153,
#      'dateModified': 1528176301,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 2,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-tk4btems7o4r4auoh4pb',
#     'fields': {'name': 'mozphab',
#      'vcs': 'git',
#      'callsign': 'MOZPHAB',
#      'shortName': 'mozphab',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1503000270,
#      'dateModified': 1524499137,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 27,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-w6s5f25vl5plrv453nmf',
#     'fields': {'name': 'mozilla-central-unified',
#      'vcs': 'hg',
#      'callsign': 'MCU',
#      'shortName': 'mcu',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1541709360,
#      'dateModified': 1557937956,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 17,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-qs76ffvu7b4qfuoyqc4s',
#     'fields': {'name': 'build-tools',
#      'vcs': 'hg',
#      'callsign': 'BUILDT',
#      'shortName': 'build-tools',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Tools used by Mozilla Release Engineering'},
#      'spacePHID': None,
#      'dateCreated': 1524498262,
#      'dateModified': 1525886194,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 12,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-e5vicqlsj5yqdj7hqctw',
#     'fields': {'name': 'phabricator-qa-stage',
#      'vcs': 'hg',
#      'callsign': 'PHABRICATORQASTAGE',
#      'shortName': 'phabricator-qa-stage',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1521731473,
#      'dateModified': 1742403311,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 6,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-7ppgekfxydtcwhw2fe3v',
#     'fields': {'name': 'bmo-extensions',
#      'vcs': 'git',
#      'callsign': 'BMOEXTENSIONS',
#      'shortName': 'bmo-extensions',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [],
#       'trackRules': ['master'],
#       'permanentRefRules': ['master']},
#      'defaultBranch': 'master',
#      'description': {'raw': ''},
#      'spacePHID': None,
#      'dateCreated': 1503589236,
#      'dateModified': 1508943970,
#      'policy': {'view': 'public',
#       'edit': 'admin',
#       'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 32,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-4gxyz2v6drcoelhqjb6i',
#     'fields': {'name': 'ietf-review',
#      'vcs': 'git',
#      'callsign': 'IETFREVIEW',
#      'shortName': 'ietf-review',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': 'IETF Drafts and Standards Review'},
#      'spacePHID': None,
#      'dateCreated': 1590768335,
#      'dateModified': 1590768607,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 44,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-xuo5uvxm4pu73tisbkou',
#     'fields': {'name': 'cypress-failed',
#      'vcs': 'hg',
#      'callsign': 'CYPRESSFAILED',
#      'shortName': 'cypress-failed',
#      'status': 'inactive',
#      'isImporting': True,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'Cypress project branch - failed import.'},
#      'spacePHID': None,
#      'dateCreated': 1714744300,
#      'dateModified': 1715010436,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 31,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-mibdni6s5bklhno6l37v',
#     'fields': {'name': 'ietf',
#      'vcs': 'git',
#      'callsign': 'IETF',
#      'shortName': 'ietf',
#      'status': 'inactive',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'master',
#      'description': {'raw': 'IETF Drafts and Standards\n'},
#      'spacePHID': None,
#      'dateCreated': 1585066258,
#      'dateModified': 1590768691,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'no-one'}},
#     'attachments': {}},
#    {'id': 54,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-uj5lvsds4cct3si523bp',
#     'fields': {'name': 'infra-testing-autoland',
#      'vcs': 'git',
#      'callsign': 'INFRATESTINGAUTOLAND',
#      'shortName': 'infra-testing-autoland',
#      'status': 'active',
#      'isImporting': True,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': ['refs/head/autoland'],
#       'trackRules': [],
#       'permanentRefRules': ['autoland']},
#      'defaultBranch': 'autoland',
#      'description': {'raw': 'Production repository in the mozilla-firefox GitHub org, used to test the production setup.'},
#      'spacePHID': None,
#      'dateCreated': 1745826789,
#      'dateModified': 1745890327,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 43,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-64m24iw6zry3xv5vtxhy',
#     'fields': {'name': 'failed-import',
#      'vcs': 'hg',
#      'callsign': 'FAILEDIMPORT',
#      'shortName': 'failed-import',
#      'status': 'inactive',
#      'isImporting': True,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'repo with failed import'},
#      'spacePHID': None,
#      'dateCreated': 1714507076,
#      'dateModified': 1714744264,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'users'}},
#     'attachments': {}},
#    {'id': 30,
#     'type': 'REPO',
#     'phid': 'PHID-REPO-42qey76qliuiwvz5nqxr',
#     'fields': {'name': 'releases/mozilla-beta',
#      'vcs': 'hg',
#      'callsign': 'RMOZILLABETA',
#      'shortName': 'mozilla-beta',
#      'status': 'active',
#      'isImporting': False,
#      'almanacServicePHID': None,
#      'refRules': {'fetchRules': [], 'trackRules': [], 'permanentRefRules': []},
#      'defaultBranch': 'default',
#      'description': {'raw': 'https://hg.mozilla.org/releases/mozilla-beta/'},
#      'spacePHID': None,
#      'dateCreated': 1567562843,
#      'dateModified': 1742382608,
#      'policy': {'view': 'users', 'edit': 'admin', 'diffusion.push': 'no-one'}},
#     'attachments': {}}],
#   'maps': {},
#   'query': {'queryKey': None},
#   'cursor': {'limit': 100, 'after': None, 'before': None, 'order': None}},
#  'error_code': None,
#  'error_info': None}

# %% [markdown]
# Get revision for a bug

# %%
operation = "differential.revision.search"
API_URL = f"{BASE_URL}/{operation}"

payload = {
    "api.token": API_TOKEN,
    "constraints[query]": "1643191"
}

requests.post(API_URL, data=payload).json()
# Out:
# {'result': {'data': [{'id': 95953,
#     'type': 'DREV',
#     'phid': 'PHID-DREV-56yisl7nav5d2eooyh6j',
#     'fields': {'stackGraph': {'PHID-DREV-56yisl7nav5d2eooyh6j': ['PHID-DREV-sygjp2ic7j4utyvdco4x'],
#       'PHID-DREV-sygjp2ic7j4utyvdco4x': ['PHID-DREV-53wkrrfagb4daxyj7piy'],
#       'PHID-DREV-53wkrrfagb4daxyj7piy': []},
#      'title': 'Bug 1643191 - Check for 3rdPartyStorage permission items in identity panel in storage access doorhanger test. r=timhuang!',
#      'uri': 'https://phabricator.services.mozilla.com/D95953',
#      'authorPHID': 'PHID-USER-oxzqolgjw7bhoaqeggzz',
#      'status': {'value': 'published',
#       'name': 'Closed',
#       'closed': True,
#       'color.ansi': 'cyan'},
#      'repositoryPHID': 'PHID-REPO-saax4qdxlbbhahhp2kg5',
#      'diffPHID': 'PHID-DIFF-q6d35kuz3hevsxo5nl67',
#      'diffID': '364513',
#      'summary': '',
#      'testPlan': '',
#      'isDraft': False,
#      'holdAsDraft': False,
#      'dateCreated': 1604535964,
#      'dateModified': 1607595448,
#      'policy': {'view': 'public', 'edit': 'PHID-PROJ-njo5uuqyyq3oijbkhy55'},
#      'bugzilla.bug-id': '1643191',
#      'uplift.request': []},
#     'attachments': {}},
#    {'id': 95655,
#     'type': 'DREV',
#     'phid': 'PHID-DREV-sygjp2ic7j4utyvdco4x',
#     'fields': {'stackGraph': {'PHID-DREV-sygjp2ic7j4utyvdco4x': ['PHID-DREV-53wkrrfagb4daxyj7piy'],
#       'PHID-DREV-53wkrrfagb4daxyj7piy': [],
#       'PHID-DREV-56yisl7nav5d2eooyh6j': ['PHID-DREV-sygjp2ic7j4utyvdco4x']},
#      'title': 'Bug 1643191 - Add a test for the 3rdPartyStorage permissions. r=pbz!,johannh',
#      'uri': 'https://phabricator.services.mozilla.com/D95655',
#      'authorPHID': 'PHID-USER-oxzqolgjw7bhoaqeggzz',
#      'status': {'value': 'published',
#       'name': 'Closed',
#       'closed': True,
#       'color.ansi': 'cyan'},
#      'repositoryPHID': 'PHID-REPO-saax4qdxlbbhahhp2kg5',
#      'diffPHID': 'PHID-DIFF-7inotsomugc5udznei4q',
#      'diffID': '364512',
#      'summary': '',
#      'testPlan': '',
#      'isDraft': False,
#      'holdAsDraft': False,
#      'dateCreated': 1604376408,
#      'dateModified': 1607595448,
#      'policy': {'view': 'public', 'edit': 'PHID-PROJ-njo5uuqyyq3oijbkhy55'},
#      'bugzilla.bug-id': '1643191',
#      'uplift.request': []},
#     'attachments': {}},
#    {'id': 94703,
#     'type': 'DREV',
#     'phid': 'PHID-DREV-53wkrrfagb4daxyj7piy',
#     'fields': {'stackGraph': {'PHID-DREV-53wkrrfagb4daxyj7piy': [],
#       'PHID-DREV-sygjp2ic7j4utyvdco4x': ['PHID-DREV-53wkrrfagb4daxyj7piy'],
#       'PHID-DREV-56yisl7nav5d2eooyh6j': ['PHID-DREV-sygjp2ic7j4utyvdco4x']},
#      'title': 'Bug 1643191 - Show storage access permissions in the identity panel. r=pbz!,johannh!',
#      'uri': 'https://phabricator.services.mozilla.com/D94703',
#      'authorPHID': 'PHID-USER-oxzqolgjw7bhoaqeggzz',
#      'status': {'value': 'published',
#       'name': 'Closed',
#       'closed': True,
#       'color.ansi': 'cyan'},
#      'repositoryPHID': 'PHID-REPO-saax4qdxlbbhahhp2kg5',
#      'diffPHID': 'PHID-DIFF-pbw2g2ct65j35vz6yocp',
#      'diffID': '364511',
#      'summary': '\nThis patch adds storage access permission items in the identity panel. This is a new\nclass of permission - multiple permission items might exist for the category i.e.\none for each third-party that has been granted access. To achieve this, we add support\nfor an "anchorfor" attribute in the permission list markup, which when present will\nsignal to the code that the element is to be the container for permission items of type\nmatching the value of the attribute. This hence adds support generally for categorical\npermission types.',
#      'testPlan': '',
#      'isDraft': False,
#      'holdAsDraft': False,
#      'dateCreated': 1603697990,
#      'dateModified': 1607595447,
#      'policy': {'view': 'public', 'edit': 'PHID-PROJ-njo5uuqyyq3oijbkhy55'},
#      'bugzilla.bug-id': '1643191',
#      'uplift.request': []},
#     'attachments': {}}],
#   'maps': {},
#   'query': {'queryKey': None},
#   'cursor': {'limit': 100, 'after': None, 'before': None, 'order': None}},
#  'error_code': None,
#  'error_info': None}

# %% [markdown]
# Get the diff for a revision

# %%
operation = "differential.diff.search"
API_URL = f"{BASE_URL}/{operation}"

payload = {
    "api.token": API_TOKEN,
    "constraints[revisionPHIDs][0]": "PHID-DREV-53wkrrfagb4daxyj7piy"
}

requests.post(API_URL, data=payload).json()

# %%
phab = Phabricator(
    host=BASE_URL,
    token=API_TOKEN,
)

# Get all transactions (including comments) for this DREV
txns = phab.transaction.search(
    objectIdentifier="PHID-DREV-53wkrrfagb4daxyj7piy",
    limit=100,
)

# print(txns)

for txn in txns["data"]:
    ttype = txn["type"]
    # "comment" transactions are the overall review comments
    if ttype == "comment":
        # Comments are usually in txn["comments"], each with content["raw"]
        for c in txn.get("comments", []):
            author = c.get("authorPHID")
            text = c.get("content", {}).get("raw")
            created = txn["dateCreated"]
            print(f"Comment by {author} at {created}:")
            print(text)
            print("-" * 40)
# Out:
# Comment by PHID-USER-qlxs3e2gjycjgcffqf6k at 1604610688:
# Tests are in D95655
# ----------------------------------------
# Comment by PHID-APPS-PhabricatorHeraldApplication at 1604610657:
# This revision requires a [[https://firefox-source-docs.mozilla.org/testing/testing-policy/ | Testing Policy]] Project Tag to be set before landing. Please apply one of `testing-approved`, `testing-exception-unchanged`, `testing-exception-ui`, `testing-exception-elsewhere`, `testing-exception-other`.
# ----------------------------------------
# Comment by PHID-USER-qlxs3e2gjycjgcffqf6k at 1604610657:
# Thanks!
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1604536130:
# >>! In D94703#3085012, @johannh wrote:
# > Seems good overall, needs some tests :)
#
# Tests are up: D95655 and D95953.
# ----------------------------------------
# Comment by PHID-USER-xjz55dyhhufbz6byzuyt at 1604495314:
# Thanks!
# ----------------------------------------
# Comment by PHID-USER-cje4weq32o3xyuegalpj at 1604475236:
#
# Code analysis found 1 defect in the diff 362647:
#  - 1 defect found by file-whitespace (Mozlint)
#
# You can run this analysis locally with:
#  - `./mach lint --warnings --outgoing`
#
# If you see a problem in this automated review, [please report it here](https://bugzilla.mozilla.org/enter_bug.cgi?product=Firefox+Build+System&component=Source+Code+Analysis&short_desc=[Automated+review]+UPDATE&comment=**Phabricator+URL:**+https://phabricator.services.mozilla.com/...&format=__default__).
#
# You can view these defects on [the code-review frontend](https://code-review.moz.tools/#/diff/362647) and on [Treeherder](https://treeherder.mozilla.org/#/jobs?repo=try&revision=9a22ec2b2487c48afc9d6de1a71216018f4f61d9).
#
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1604473759:
# >>! In D94703#3091569, @pbz wrote:
# >>>! In D94703#3089324, @nhnt11 wrote:
# >>>>! In D94703#3085012, @johannh wrote:
# >>
# >>> We have a way to scroll the list in the protections panel, maybe that is helpful here?
# >>
# >> Hmm, in the protections panel these are in sub-views, which PanelMultiView attempts to size based on the main view. So overflow works easily there. But here, it's in the main view, and I think getting PanelMultiView to be intelligent enough to take max-heights and overflow: auto into account should be done in a separate bug.
# >
# > Sounds good, could you please file a bug? Ideally, we should get this fixed in 84, would also be good for the `open-protocol-handler` permission.
#
# Filed bug 1675198
#
# > The horizontal overflow (when the origin is really long) is probably much more common and should be, at least partially, addressed in this patch. It seems like we wrap at `-` but not at `.`.
#
# Fixed, but special cased for the 3rdPartyStorage permissions right now (createPermissionItem accepts a new boolean). This is because XUL labels always wrap if you set their textContent, so to stop this we need to set the value attribute along with crop="end" and a tooltip. Note that simply using CSS white-space: nowrap and text-overflow: ellipsis doesn't quite do the trick - the label simply takes up too much space and the permission item overflows the width of the panel. I could not fix this trivially by setting max-widths or playing with flex values.... so I went with this XUL-y solution for this XUL-y problem.
#
# (https://developer.mozilla.org/en-US/docs/Archive/Mozilla/XUL/label#Wrapping)
#
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1604473759:
# >>! In D94703#3091569, @pbz wrote:
# >>>! In D94703#3089324, @nhnt11 wrote:
# >>>>! In D94703#3085012, @johannh wrote:
# >>
# >>> We have a way to scroll the list in the protections panel, maybe that is helpful here?
# >>
# >> Hmm, in the protections panel these are in sub-views, which PanelMultiView attempts to size based on the main view. So overflow works easily there. But here, it's in the main view, and I think getting PanelMultiView to be intelligent enough to take max-heights and overflow: auto into account should be done in a separate bug.
# >
# > Sounds good, could you please file a bug? Ideally, we should get this fixed in 84, would also be good for the `open-protocol-handler` permission.
#
# Filed bug 1675198
#
# > The horizontal overflow (when the origin is really long) is probably much more common and should be, at least partially, addressed in this patch. It seems like we wrap at `-` but not at `.`.
#
# Fixed, but special cased for the 3rdPartyStorage permissions right now (createPermissionItem accepts a new boolean). This is because XUL labels always wrap if you set their textContent, so to stop this we need to set the value attribute along with crop="end" and a tooltip. Note that simply using CSS white-space: nowrap and text-overflow: ellipsis doesn't quite do the trick - the label simply takes up too much space and the permission item overflows the width of the panel. I could not fix this trivially by setting max-widths or playing with flex values.... so I went with this XUL-y solution for this XUL-y problem.
#
#
# ----------------------------------------
# Comment by PHID-USER-xjz55dyhhufbz6byzuyt at 1604410476:
# >>! In D94703#3089324, @nhnt11 wrote:
# >>>! In D94703#3085012, @johannh wrote:
# >
# >> We have a way to scroll the list in the protections panel, maybe that is helpful here?
# >
# > Hmm, in the protections panel these are in sub-views, which PanelMultiView attempts to size based on the main view. So overflow works easily there. But here, it's in the main view, and I think getting PanelMultiView to be intelligent enough to take max-heights and overflow: auto into account should be done in a separate bug.
#
# Sounds good, could you please file a bug? Ideally, we should get this fixed in 84, would also be good for the `open-protocol-handler` permission.
#
# The horizontal overflow (when the origin is really long) is probably much more common and should be, at least partially, addressed in this patch. It seems like we wrap at `-` but not at `.`.
# ----------------------------------------
# Comment by PHID-USER-cje4weq32o3xyuegalpj at 1604377202:
#
# Code analysis found 1 defect in the diff 361893:
#  - 1 defect found by file-whitespace (Mozlint)
#
# You can run this analysis locally with:
#  - `./mach lint --warnings --outgoing`
#
# If you see a problem in this automated review, [please report it here](https://bugzilla.mozilla.org/enter_bug.cgi?product=Firefox+Build+System&component=Source+Code+Analysis&short_desc=[Automated+review]+UPDATE&comment=**Phabricator+URL:**+https://phabricator.services.mozilla.com/...&format=__default__).
#
# You can view these defects on [the code-review frontend](https://code-review.moz.tools/#/diff/361893) and on [Treeherder](https://treeherder.mozilla.org/#/jobs?repo=try&revision=ab6dfb66c87e6c22233083c62cafa8ee930d84ec).
#
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1604376443:
# >>! In D94703#3085012, @johannh wrote:
# > Seems good overall, needs some tests :)
# >
# > It's worth noting that we are thus moving away from considering the content blocking log for displaying exceptions and instead using the permission manager, this has the advantage that sites can be listed/removed without actually being present on the page, though it may have downsides that I can't think of at the moment.
# >
# > Again, it would be great if this could also cover regular cookie exceptions to avoid regressing the old exceptions UI in protections panel. When we support that it's definitely not going to be as clean-cut as this implementation, e.g. https://searchfox.org/mozilla-central/rev/7b07725fe9dc5d59a525990fc1dba78bc8b82af1/browser/base/content/browser-siteProtections.js#857
# >
# > Also please make sure that we have removing the old UI on our radar.
#
# Filed bug 1674958
#
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1604376070:
# >>! In D94703#3085012, @johannh wrote:
#
# > We have a way to scroll the list in the protections panel, maybe that is helpful here?
#
# Hmm, in the protections panel these are in sub-views, which PanelMultiView attempts to size based on the main view. So overflow works easily there. But here, it's in the main view, and I think getting PanelMultiView to be intelligent enough to take max-heights and overflow: auto into account should be done in a separate bug.
# ----------------------------------------
# Comment by PHID-USER-qlxs3e2gjycjgcffqf6k at 1604325324:
# Seems good overall, needs some tests :)
#
# It's worth noting that we are thus moving away from considering the content blocking log for displaying exceptions and instead using the permission manager, this has the advantage that sites can be listed/removed without actually being present on the page, though it may have downsides that I can't think of at the moment.
#
# Again, it would be great if this could also cover regular cookie exceptions to avoid regressing the old exceptions UI in protections panel. When we support that it's definitely not going to be as clean-cut as this implementation, e.g. https://searchfox.org/mozilla-central/rev/7b07725fe9dc5d59a525990fc1dba78bc8b82af1/browser/base/content/browser-siteProtections.js#857
#
# Also please make sure that we have removing the old UI on our radar.
#
# > Ugh, PanelMultiView is making this a bit tricky. Seems like it's calculating the height of the panel without taking overflow into account... stay tuned.
#
# We have a way to scroll the list in the protections panel, maybe that is helpful here?
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1604077778:
# >>! In D94703#3077683, @pbz wrote:
# > - Now that we're introducing double keyed permissions to the UI, the permission list size will no longer be limited by the amount of permission types that can bet set. While it's probably an edge case, we should still make sure that vertical overflow is hidden behind a scrollbar if the list gets too long. At the moment the overflow is hidden and therefore inaccessible.
#
# Ugh, PanelMultiView is making this a bit tricky. Seems like it's calculating the height of the panel without taking overflow into account... stay tuned.
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1604076428:
# >>! In D94703#3077683, @pbz wrote:
# > Great overall! I just had some concerns:
# >
# > - It would be good to get test coverage for the new permission anchors.
#
# Coming soon ™️
#
# > - I've noticed that when the site URI is really long we don't wrap properly and the panel content clips (including revoke buttons):
# >   {F2549618}
#
# Ah yes, I asked epang about this but haven't heard back yet - I'll nudge him. I think I can just do something reasonable here for now and we can land a follow-up if Eric has a better suggestion.
#
# > - Now that we're introducing double keyed permissions to the UI, the permission list size will no longer be limited by the amount of permission types that can bet set. While it's probably an edge case, we should still make sure that vertical overflow is hidden behind a scrollbar if the list gets too long. At the moment the overflow is hidden and therefore inaccessible.
#
# Good call, thanks.
# ----------------------------------------
# Comment by PHID-USER-xjz55dyhhufbz6byzuyt at 1604075809:
# Great overall! I just had some concerns:
#
# - It would be good to get test coverage for the new permission anchors.
#
# - I've noticed that when the site URI is really long we don't wrap properly and the panel content clips (including revoke buttons):
#   {F2549618}
#
# - Now that we're introducing double keyed permissions to the UI, the permission list size will no longer be limited by the amount of permission types that can bet set. While it's probably an edge case, we should still make sure that vertical overflow is hidden behind a scrollbar if the list gets too long. At the moment the overflow is hidden and therefore inaccessible.
#
# ----------------------------------------
# Comment by PHID-USER-cje4weq32o3xyuegalpj at 1604071885:
#
# Code analysis found 1 defect in the diff 360846:
#  - 1 defect found by file-whitespace (Mozlint)
#
# You can run this analysis locally with:
#  - `./mach lint --warnings --outgoing`
#
# If you see a problem in this automated review, [please report it here](https://bugzilla.mozilla.org/enter_bug.cgi?product=Firefox+Build+System&component=Source+Code+Analysis&short_desc=[Automated+review]+UPDATE&comment=**Phabricator+URL:**+https://phabricator.services.mozilla.com/...&format=__default__).
#
# You can view these defects on [the code-review frontend](https://code-review.moz.tools/#/diff/360846) and on [Treeherder](https://treeherder.mozilla.org/#/jobs?repo=try&revision=ba6fa10adb6dfb1341594fdd419f15b06da89ac6).
#
# ----------------------------------------
# Comment by PHID-USER-cje4weq32o3xyuegalpj at 1604071506:
#
# Code analysis found 1 defect in the diff 360843:
#  - 1 defect found by file-whitespace (Mozlint)
#
# You can run this analysis locally with:
#  - `./mach lint --warnings --outgoing`
#
# If you see a problem in this automated review, [please report it here](https://bugzilla.mozilla.org/enter_bug.cgi?product=Firefox+Build+System&component=Source+Code+Analysis&short_desc=[Automated+review]+UPDATE&comment=**Phabricator+URL:**+https://phabricator.services.mozilla.com/...&format=__default__).
#
# You can view these defects on [the code-review frontend](https://code-review.moz.tools/#/diff/360843) and on [Treeherder](https://treeherder.mozilla.org/#/jobs?repo=try&revision=802bc87339057dbf96248b79df81a63b05505984).
#
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1604070564:
# >>! In D94703#3077071, @pbz wrote:
# > As we discussed earlier, this needs to be rebased on latest central. The double key splitting with `^` I've added in D92947 can be reused. As a follow up we can look into refactoring the protocol handler permission to also use the anchor logic (which seems a lot nicer!).
#
# Rebased! :)
# ----------------------------------------
# Comment by PHID-USER-xjz55dyhhufbz6byzuyt at 1604069773:
# As we discussed earlier, this needs to be rebased on latest central. The double key splitting with `^` I've added in D92947 can be reused. As a follow up we can look into refactoring the protocol handler permission to also use the anchor logic (which seems a lot nicer!).
# ----------------------------------------
# Comment by PHID-USER-xjz55dyhhufbz6byzuyt at 1603994659:
# Thanks for taking the time to build a more generic solution! I like the approach with the anchors. Only had a brief look, but I can take a closer look at the patch tomorrow.
#
# I'm currently landing a patch for the `open-protocol-handler` permission which also is double keyed and uses a "permission container": https://hg.mozilla.org/integration/autoland/rev/9dc529fe7e3cb68de9f8d7aeba9763c99bbcecf1
# However, your approach seems nicer, so perhaps we can also switch the protocol handler permission over to it as a follow up.
#
# I've updated gPermissionObject to have a getter method which splits by `^` delimiter before it looks up the permission by key: https://hg.mozilla.org/integration/autoland/diff/9dc529fe7e3cb68de9f8d7aeba9763c99bbcecf1/browser/modules/SitePermissions.jsm
# ----------------------------------------
# Comment by PHID-USER-xjz55dyhhufbz6byzuyt at 1603994659:
# Thanks for taking the time to build a more generic solution! I like the approach with the anchors. Only had a brief look, but I can take a closer look at the patch tomorrow.
#
# I'm currently landing a patch for the `open-protocol-handler` permission which also is double keyed and uses a "permission container": https://hg.mozilla.org/integration/autoland/rev/9dc529fe7e3cb68de9f8d7aeba9763c99bbcecf1
# However, your approach seems nicer, so perhaps we can rebase on that.
#
# I've updated gPermissionObject to have a getter method which splits by `^` delimiter before it looks up the permission by key: https://hg.mozilla.org/integration/autoland/diff/9dc529fe7e3cb68de9f8d7aeba9763c99bbcecf1/browser/modules/SitePermissions.jsm
# ----------------------------------------
# Comment by PHID-USER-52tll3zmlcopd5aoarnv at 1603863737:
# Rubberstamp the Fluent bits.
# ----------------------------------------
# Comment by PHID-USER-oxzqolgjw7bhoaqeggzz at 1603848806:
# Tests are coming in a separate patch. I'm going to need advice on what kind of scenarios are worth testing (e.g. checking that other permissions don't break, etc)
# ----------------------------------------
# Comment by PHID-USER-cje4weq32o3xyuegalpj at 1603700556:
#
# Code analysis found 1 defect in the diff 357958:
#  - 1 defect found by file-whitespace (Mozlint)
#
# You can run this analysis locally with:
#  - `./mach lint --warnings --outgoing`
#
# If you see a problem in this automated review, [please report it here](https://bugzilla.mozilla.org/enter_bug.cgi?product=Firefox+Build+System&component=Source+Code+Analysis&short_desc=[Automated+review]+UPDATE&comment=**Phabricator+URL:**+https://phabricator.services.mozilla.com/...&format=__default__).
#
# You can view these defects on [the code-review frontend](https://code-review.moz.tools/#/diff/357958) and on [Treeherder](https://treeherder.mozilla.org/#/jobs?repo=try&revision=371af00a2da4d87514351749ad298a5d49296f6a).
#
# ----------------------------------------

# %% [markdown]
# Get raw diff and format it

# %%
operation = "differential.getrawdiff"
API_URL = f"{BASE_URL}/{operation}"

payload = {
    "api.token": API_TOKEN,
    "diffID": "946305"
}

diff = requests.post(API_URL, data=payload).json()

response = phab.differential.getrawdiff(diffID='946305')

print(response.response)

patch = PatchSet(diff["result"])

for patched_file in patch:
    print(f"📄 {patched_file.path}")
    for hunk in patched_file:
        print(f"  🔢 Hunk: {hunk.source_start}:{hunk.source_length} → {hunk.target_start}:{hunk.target_length}")
        for line in hunk:
            if line.is_added:
                print(f"    ➕ {line.value.strip()}")
            elif line.is_removed:
                print(f"    ➖ {line.value.strip()}")

# %% [markdown]
# Get commmit message for a diff

# %%
response = phab.diffusion.commit.search(
    constraints={
        'ids': [946314]
    }
)

pprint(response.response)
# Out:
# {'cursor': {'after': None, 'before': None, 'limit': 100, 'order': None},
#  'data': [{'attachments': {},
#            'fields': {'auditStatus': {'closed': True,
#                                       'color.ansi': None,
#                                       'name': 'No Audits',
#                                       'value': 'none'},
#                       'author': {'email': 'philringnalda@gmail.com',
#                                  'epoch': None,
#                                  'identityPHID': 'PHID-RIDT-kpxu5wfnlpt3cu33kmi3',
#                                  'name': 'Phil Ringnalda',
#                                  'raw': 'Phil Ringnalda '
#                                         '<philringnalda@gmail.com>',
#                                  'userPHID': 'PHID-USER-sbnc5ih3p7zgvgpizobs'},
#                       'committer': {'email': None,
#                                     'epoch': 1504763335,
#                                     'identityPHID': None,
#                                     'name': None,
#                                     'raw': None,
#                                     'userPHID': None},
#                       'identifier': '634cb312d32284ddedd3941a8a5d0b0ea38e070e',
#                       'isImported': True,
#                       'isUnreachable': False,
#                       'message': 'Backed out 3 changesets (bug 1394603) for '
#                                  'reftest syntax error\n'
#                                  'CLOSED TREE\n'
#                                  '\n'
#                                  'Backed out changeset 44117208f321 (bug '
#                                  '1394603)\n'
#                                  'Backed out changeset 31088c59d895 (bug '
#                                  '1394603)\n'
#                                  'Backed out changeset 20551d68f602 (bug '
#                                  '1394603)\n'
#                                  '\n'
#                                  'MozReview-Commit-ID: 4F4jSQ8GyfG',
#                       'policy': {'edit': 'users', 'view': 'users'},
#                       'repositoryPHID': 'PHID-REPO-w6s5f25vl5plrv453nmf'},
#            'id': 946314,
#            'phid': 'PHID-CMIT-dvgagkk2qcd6krha2qrl',
#            'type': 'CMIT'}],
#  'maps': {},
#  'query': {'queryKey': None}}

# %% [markdown]
# - Get all the differential revisions (DREV) from last year until now
# - For each bug id from bugs_with_added_regressor_info.csv fetch its corresponding differential revision
# - For each DREV, get its diff and attach it as a new column to its corresponding bug id from the bugs_with_added_regressor_info.csv

# %%
MOZILLA_CENTRAL_PHID = "PHID-REPO-saax4qdxlbbhahhp2kg5"
LIMIT = 100 # page size

# Time range: last 7 days
now = datetime.now()
start_time = now - timedelta(days=365)
start_epoch = int(start_time.timestamp())

all_revisions_list = []
after_cursor = None

while True:

    response = phab.differential.revision.search(
        constraints={
            'createdStart':start_epoch,
            'repositoryPHIDs':[MOZILLA_CENTRAL_PHID]
        },
        order= 'oldest',
        limit= LIMIT,
        after= after_cursor
    )

    data = response['data']
    all_revisions_list.extend(data)

    cursor = response['cursor']
    if cursor['after'] is None:
        break
    after_cursor = cursor['after']


# for rev in all_revisions_list:
#     created_time = datetime.fromtimestamp(rev['fields']['dateCreated']).strftime('%Y-%m-%d %H:%M:%S')
#     print(f"ID: {rev['id']}, PHID: {rev['phid']}, Title: {rev['fields']['title']}, Created: {created_time}")

all_revisions_df = pd.DataFrame(all_revisions_list)
all_revisions_df.to_csv("../datasets/all_differential_revisions.csv", index=False)

# %%
all_revisions_df = pd.read_csv("../datasets/all_differential_revisions.csv")
all_revisions_df['fields'] = all_revisions_df['fields'].apply(ast.literal_eval)
all_revisions_list = all_revisions_df.to_dict(orient='records')


bugs_df = pd.read_csv("../datasets/bugs_with_added_regressor_info.csv")
bugs_df['regressed_perf_tests'] = bugs_df['regressed_perf_tests'].apply(ast.literal_eval)
bugs_list = bugs_df.to_dict(orient='records')


# transform to dict for faster lookup
all_revisions_dict = {}

for drev in all_revisions_list:
    drev_bugzilla_bug_id = drev['fields']['bugzilla.bug-id']

    if drev_bugzilla_bug_id:
        all_revisions_dict[int(drev_bugzilla_bug_id)] = drev

bugs_with_drev_list = []

for bug in bugs_list:
    bug_with_drev = bug

    bugzilla_bug_id = bug['bug_id']
    drev_for_bug = all_revisions_dict.get(bugzilla_bug_id)

    bug_with_drev['drev_id'] = None
    bug_with_drev['diff_id'] = None

    if drev_for_bug:
        bug_with_drev['drev_id'] = drev_for_bug['id']
        bug_with_drev['diff_id'] = drev_for_bug['fields']['diffID']

    bugs_with_drev_list.append(bug_with_drev)

bugs_with_drev_df = pd.DataFrame(bugs_with_drev_list)
bugs_with_drev_df.to_csv("../datasets/bugs_with_drev.csv", index=False)


bugs_with_diff_list = []

for bug in bugs_with_drev_list:
    bug_diff_id = bug.get('diff_id')

    if bug_diff_id:

        bug_with_diff = bug

        raw_diff = phab.differential.getrawdiff(diffID = str(bug_diff_id)).response

        bug['raw_diff'] = raw_diff
        bugs_with_diff_list.append(bug_with_diff)


bugs_with_drev_df = pd.DataFrame(bugs_with_diff_list)

bugs_with_drev_df.to_json("../datasets/bugs_with_diff.jsonl", orient="records", lines=True)
